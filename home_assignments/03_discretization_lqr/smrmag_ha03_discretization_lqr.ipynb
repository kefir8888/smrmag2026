# %% [markdown]
# ## Домашнее задание 3

# %% [markdown]
# ### Задача 1
#
# Доделайте все из семинарского ноутбука. В классруме нужно будет приложить nhb файла - модифицированный семинарский, модифицированный этот, и видео (см. ниже).
#
# Если в семинарском ноутбуке задан некоторый вопрос, ответьте на него прямо там. Можно делать это достаточно подробно, а если чего-то не знаете, там об этом можно написать.

# %% [markdown]
# ### Задача 2
#
# Покажите, что квадратная матрица $A$ коммутирует с $e^A$.

# %% [markdown]
# YOUR MARKDOWN HERE

# %% [markdown]
# ### Задача 3
#
# Рассмотрим модель пружинного маятника на горизонтальной плоскости.
#
# Его вектор состояния имеет вид
#
# $x = \begin{pmatrix}
# p \\
# \dot{p}
# \end{pmatrix}$
#
# Уравнение динамики системы в непрерывном случае таково:
#
# $\dot{x} =  \begin{pmatrix}
# 0 & 1 \\
# {- \frac{k}{m}} & 0
# \end{pmatrix} x$
#
# Пусть симуляция этой системы производится как
#
# $x_{k+1} = x_k + \Delta t \dot{x}_k$
#
# Найдите, как изменяется полная энергия системы за один шаг симуляции.

# %% [markdown]
# YOUR MARKDOWN HERE

# %% [markdown]
# ### Задача 4
#
# Вспомните формализм Лагранжа. Посмотрите еще раз на то, как на семинаре было получено уравнение движения маятника. Осознайте, откуда там что взялось, как сделан каждый шаг.
#
# Реализуйте симуляцию маятника. Его можно нарисовать с помощью одного отрезка и одного круга. Подвешен он может быть в середине окна. Немного хитрая штука - это чтобы нулевой угол соответствовал нижнему положению и направление вращения было корректным. Для этого надо разобраться с осями.
#
# Сравните траектории маятника, когда используется полная и линеаризованная динамическая модель.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Задача 5
#
# Выведите и линеаризуйте динамику двух маятников, связанных пружиной.
# Нулевой угол у них, когда они висят вниз, пружина в этом состоянии не деформирована (и создает нулевую силу).
# Жесткость ее $k$, масса точечных грузов $m$, длина $l$, они в поле тяготения $g$.
#
# - Какой у этой системы вектор состояния? Почему? Какой он размерности?
# - Запишите кинетическую энергию системы. Запишите потенциальную энергию системы. Для потенциальной действуйте в упрощении, пренебрегая отклонением пружины от горизонтали. Считайте, что углы малые (но пока что только в этом месте) и что растяжение пружины можно найти через длину маятника и два синуса
# - Запишите лагранжиан системы и два уравнения движения, полученные с помощью уравнения Эйлера-Лагранжа. Выразите из них вторые производные углов
# - Линеаризуйте систему в окрестности нулевых углов, описывая, чем и почему пренебрегаем. Запишите систему в виде $\dot{x} = A x$

# %% [markdown]
# YOUR MARKDOWN HERE

# %% [markdown]
# ### Задача 6
#
# Реализуйте симуляцию этой системы. Рисование можно взять задачи 4, просто маятников будет два.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Задача 7
#
# Добавьте управление правым маятником по моменту.
#
# Реализуйте контроллер, который стабилизирует систему. Это может быть PD-регулятор, который пытается привести правый маятник в 0.
#
# Примените LQR для стабилизации этой системы. Это можно сделать по аналогии с тем, что было сделано на семинаре. Сравните получившиеся траектории и стоимость траекторий согласно выбранному критерию.
#
# Конкретные шаги, которые нужно будет предпринять:
# - Линеаризуйте систему в окрестности положения равновесия (это уже есть)
# - Определите весовые матрицы Q и R правильных размерностей
# - Решите алгебраическое уравнение Риккати с помощью scipy
# - Встройте обратную связь в цикл симуляции системы. Постройте графики углов, скоростей и момента
# - Исследуйте влияние весов в матрицах Q и R на траектории системы. Если управление дорогое, система стабилизируется быстро или медленно? Что изменится, если домножить обе матрицы Q и R на 10?
#
# Сделайте короткую (до 10 секунд) запись поведения системы и приложите ее в классруме.

# %%
# YOUR CODE HERE
